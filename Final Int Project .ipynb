# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
dataset = pd.read_csv("C:/classified-data.csv")

# %%
dataset.head()
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
sns.heatmap(dataset.isnull(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
dataset.isnull().sum()
# Out:
# Customer ID                       0
# Name                              0
# Gender                           53
# Age                               0
# Income (USD)                   4576
# Income Stability               1683
# Profession                        0
# Type of Employment             7270
# Location                          0
# Loan Amount Request (USD)         0
# Current Loan Expenses (USD)     172
# Expense Type 1                    0
# Expense Type 2                    0
# Dependents                     2493
# Credit Score                   1703
# No. of Defaults                   0
# Has Active Credit Card         1566
# Property ID                       0
# Property Age                   4850
# Property Type                     0
# Property Location               356
# Co-Applicant                      0
# Property Price                    0
# Loan Sanction Amount (USD)      340
# dtype: int64

# %%
dataset.describe()
# Out:
#                 Age  Income (USD)  Loan Amount Request (USD)  \
# count  30000.000000  2.542400e+04               30000.000000
# mean      40.092300  2.630574e+03               88826.333855
# std       16.045129  1.126272e+04               59536.949605
# min       18.000000  3.777000e+02                6048.240000
# 25%       25.000000  1.650457e+03               41177.755000
# 50%       40.000000  2.222435e+03               75128.075000
# 75%       55.000000  3.090593e+03              119964.605000
# max       65.000000  1.777460e+06              621497.820000
#
#        Current Loan Expenses (USD)    Dependents  Credit Score  \
# count                 29828.000000  27507.000000  28297.000000
# mean                    400.936876      2.253027    739.885381
# std                     242.545375      0.951162     72.163846
# min                    -999.000000      1.000000    580.000000
# 25%                     247.667500      2.000000    681.880000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  30000 non-null  object
#  1   Name                         30000 non-null  object
#  2   Gender                       29947 non-null  object
#  3   Age                          30000 non-null  int64
#  4   Income (USD)                 25424 non-null  float64
#  5   Income Stability             28317 non-null  object
#  6   Profession                   30000 non-null  object
#  7   Type of Employment           22730 non-null  object
#  8   Location                     30000 non-null  object
#  9   Loan Amount Request (USD)    30000 non-null  float64
#  10  Current Loan Expenses (USD)  29828 non-null  float64
#  11  Expense Type 1               30000 non-null  object
#  12  Expense Type 2               30000 non-null  object
# ...

# %%
dataset.dtypes
# Out:
# Customer ID                     object
# Name                            object
# Gender                          object
# Age                              int64
# Income (USD)                   float64
# Income Stability                object
# Profession                      object
# Type of Employment              object
# Location                        object
# Loan Amount Request (USD)      float64
# Current Loan Expenses (USD)    float64
# Expense Type 1                  object
# Expense Type 2                  object
# Dependents                     float64
# Credit Score                   float64
# No. of Defaults                  int64
# Has Active Credit Card          object
# Property ID                      int64
# Property Age                   float64
# Property Type                    int64
# Property Location               object
# Co-Applicant                     int64
# Property Price                 float64
# Loan Sanction Amount (USD)     float64
# dtype: object

# %%
corr= dataset.corr()
plt.figure(figsize=(10,15))
sns.heatmap(corr,annot =True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(dataset['Gender'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
dataset['Income (USD)']=dataset['Income (USD)'].fillna(dataset['Income (USD)'].median())
dataset['Current Loan Expenses (USD)']=dataset['Current Loan Expenses (USD)'].fillna(dataset['Current Loan Expenses (USD)'].median())
dataset['Dependents']=dataset['Dependents'].fillna(dataset['Dependents'].median())
dataset['Loan Sanction Amount (USD)']=dataset['Loan Sanction Amount (USD)'].fillna(dataset['Loan Sanction Amount (USD)'].median())
dataset['Property Age']=dataset['Property Age'].fillna(dataset['Property Age'].median())
dataset['Credit Score']=dataset['Credit Score'].fillna(dataset['Credit Score'].median())

# %%
dataset['Gender']=dataset['Gender'].fillna(dataset['Gender'].mode()[0])
dataset['Property Location']=dataset['Property Location'].fillna(dataset['Property Location'].mode()[0])
dataset['Type of Employment']=dataset['Type of Employment'].fillna(dataset['Type of Employment'].mode()[0])
dataset['Income Stability']=dataset['Income Stability'].fillna(dataset['Income Stability'].mode()[0])
dataset['Has Active Credit Card']=dataset['Has Active Credit Card'].fillna(dataset['Has Active Credit Card'].mode()[0])

# %%
dataset.isnull().sum()
# Out:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Income Stability               0
# Profession                     0
# Type of Employment             0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Expense Type 1                 0
# Expense Type 2                 0
# Dependents                     0
# Credit Score                   0
# No. of Defaults                0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Type                  0
# Property Location              0
# Co-Applicant                   0
# Property Price                 0
# Loan Sanction Amount (USD)     0
# dtype: int64

# %%
sns.countplot(dataset['Dependents'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %%
sns.countplot(dataset['Property Location'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Property Location', ylabel='count'>

# %%
sns.countplot(dataset['No. of Defaults'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='No. of Defaults', ylabel='count'>

# %%
dataset['Credit Score']=np.log(dataset['Credit Score'])
dataset['Credit Score'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dataset['Income (USD)']=np.log(dataset['Income (USD)'])
dataset['Income (USD)'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dataset['Loan Amount Request (USD)']=np.log(dataset['Loan Amount Request (USD)'])
dataset['Loan Amount Request (USD)'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dataset['Loan Sanction Amount (USD)']=np.log(dataset['Loan Sanction Amount (USD)'])
dataset['Loan Sanction Amount (USD)'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(dataset['Loan Amount Request (USD)'])
plt.show()
dataset['Loan Amount Request (USD)'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['Loan Sanction Amount (USD)'])
plt.show()
dataset['Loan Sanction Amount (USD)'].plot.box(figsize=(16,5))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.lineplot(x='Profession',y='Loan Sanction Amount (USD)',data=dataset,color='b',linewidth=5.0)
#fig=plt.figure(figsize=(15, 15))
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='Loan Sanction Amount (USD)'>

# %%
sns.boxplot('Loan Sanction Amount (USD)',data=dataset)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Loan Sanction Amount (USD)'>

# %%
sns.displot(dataset['Age'],bins=30)

# %%
sns.jointplot(y='Profession',x='Loan Sanction Amount (USD)',data=dataset,kind='scatter',color='b',edgecolor='r')

# %%
sns.jointplot(x='Credit Score',y='Loan Sanction Amount (USD)',data=dataset,kind='scatter',color='b',edgecolor='r')

# %%
sns.jointplot(x='Loan Amount Request (USD)',y='Loan Sanction Amount (USD)',data=dataset,kind='scatter',color='b',edgecolor='r')

# %%
sns.scatterplot(x=dataset['Credit Score'],y=dataset['Profession'])
# Out:
# <AxesSubplot:xlabel='Credit Score', ylabel='Profession'>

# %%
sns.jointplot(x='Dependents',y='Loan Sanction Amount (USD)',data=dataset,kind='scatter',color='b',edgecolor='g')

# %%
col=['Property Age','No. of Defaults','Location','Type of Employment','Customer ID','Name','Property ID','Property Location']

dataset=dataset.drop(columns=col,axis=1)

# %%
dataset.head()
# Out:
#   Customer ID               Name Gender  Age  Income (USD) Income Stability  \
# 0     C-36995   Frederica Shealy      F   56       1933.05              Low
# 1     C-33999  America Calderone      M   32       4952.91              Low
# 2      C-3770      Rosetta Verne      F   65        988.19             High
# 3     C-26480         Zoe Chitty      F   65           NaN             High
# 4     C-23459       Afton Venema      F   31       2614.77              Low
#
#   Profession     Type of Employment    Location  Loan Amount Request (USD)  \
# 0    Working            Sales staff  Semi-Urban                   72809.58
# 1    Working                    NaN  Semi-Urban                   46837.47
# 2  Pensioner                    NaN  Semi-Urban                   45593.04
# 3  Pensioner                    NaN       Rural                   80057.92
# 4    Working  High skill tech staff  Semi-Urban                  113858.89
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
col=['Gender','Expense Type 1','Expense Type 2','Income Stability','Has Active Credit Card','Profession']
le= LabelEncoder()
for col in col:
    dataset[col]=le.fit_transform(dataset[col])
#pd.get_dummies(dataset)
# Out:
#        Gender  Age  Income (USD)  Income Stability  Profession  \
# 0           0   56      1933.050                 1           7
# 1           1   32      4952.910                 1           7
# 2           0   65       988.190                 0           3
# 3           0   65      2222.435                 0           3
# 4           0   31      2614.770                 1           7
# ...       ...  ...           ...               ...         ...
# 29995       1   38      4969.410                 1           1
# 29996       1   20      1606.880                 1           7
# 29997       0   49      2222.435                 1           7
# 29998       1   38      2417.710                 1           7
# 29999       0   63      3068.240                 0           3
#
#        Loan Amount Request (USD)  Current Loan Expenses (USD)  Expense Type 1  \
# 0                       72809.58                       241.08               0
# ...

# %%
dataset.head()
# Out:
#    Gender  Age  Income (USD)  Income Stability  Profession  \
# 0       0   56      1933.050                 1           7
# 1       1   32      4952.910                 1           7
# 2       0   65       988.190                 0           3
# 3       0   65      2222.435                 0           3
# 4       0   31      2614.770                 1           7
#
#    Loan Amount Request (USD)  Current Loan Expenses (USD)  Expense Type 1  \
# 0                   72809.58                       241.08               0
# 1                   46837.47                       495.81               0
# 2                   45593.04                       171.95               0
# 3                   80057.92                       298.54               0
# 4                  113858.89                       491.41               0
#
#    Expense Type 2  Dependents  Credit Score  Has Active Credit Card  \
# 0               0         3.0        809.44                       0
# ...

# %%
x=dataset.drop(columns=['Loan Sanction Amount (USD)'],axis=1)
y=dataset['Loan Sanction Amount (USD)']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)

# %%
predict=lm.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score

# %%
r2_score(y_test,predict)
# Out:
# 0.597649810101416

# %%
mean_absolute_error(y_test,predict)
# Out:
# 21731.54937286625

# %%
mean_squared_error(y_test,predict)
# Out:
# 988025195.9301953

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train,y_train)
pred =model.predict(x_test)

from sklearn.metrics import r2_score
r2_score = r2_score(y_test,pred)

# %%
r2_score
# Out:
# 0.7485246077843142

# %%
from sklearn import tree
clf = tree.DecisionTreeRegressor()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.5235955347794101

# %%
from sklearn.svm import SVR
model = SVR()
model.fit(x_train,y_train)
pred3 = model.predict(x_test)
accuracy =r2_score(y_test,pred3)

# %%
accuracy
# Out:
# 0.0002878463167897971

# %%
from sklearn import linear_model
reg = linear_model.BayesianRidge()
reg.fit(x_train, y_train)
predic = reg.predict(x_test)
accuracy = r2_score(y_test,predic)

# %%
accuracy
# Out:
# 0.5676246826817665

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
n_samples, n_features = 10, 5
reg1 = make_pipeline(StandardScaler(),
SGDRegressor(max_iter=5000, tol=1e-3))
reg1.fit(x_train, y_train)
pr = reg1.predict(x_test)
accuracy = r2_score(y_test,pr)

# %%
accuracy
# Out:
# -25825355.116161916

# %%
lm.coef_
# Out:
# array([-1.38838604e+02, -2.90061414e+01,  5.62945121e-03,  1.87996811e+03,
#        -1.17453781e+02,  5.61176230e-01, -3.86569207e+00,  3.70029707e+02,
#         7.67919058e+02, -2.92651611e+02,  1.69036890e+02,  4.20487640e+02,
#         6.55741278e+01, -7.39239671e+00, -7.84820198e-03])

# %%
lm.intercept_
# Out:
# -125571.02150870231

# %%
lm.predict([[0,5,1933.050,1,7,72809.58,241.08,0,0,3.0,809.44,0,4,1,119933.46]])
# Out:
# array([51052.94661662])

# %%
dataset['Loan Sanction Amount (USD)']
# Out:
# 0         54607.18
# 1         37469.98
# 2         36474.43
# 3         56040.54
# 4         74008.28
#            ...
# 29995     68992.11
# 29996     46616.60
# 29997     61057.56
# 29998     99766.87
# 29999    117217.90
# Name: Loan Sanction Amount (USD), Length: 30000, dtype: float64

# %%
  #'array([51052.94661662])' is wt the predict value of the 0Th row we got which is near to the original value ie='54607.18'
